# %%
import  matplotlib.pyplot as plt
brands=["oneplus","samsung","nokia","redmi"]
x=[23,10,12,32]
c=["red","silver","yellow","blue"]
ex=[0,0,0.1,0]
plt.pie(x, labels=brands,colors=c,explode=ex,shadow=True,autopct="%.f")
plt.savefig("piechart.png",pad_inches=0.3,bbox_in)

# %%
plt.pie(x, labels=brands,colors=c,explode=ex,shadow=True,autopct="%.2f",startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd179a8d2d0>,
# ...
#  [Text(-0.6501892803051905, -0.8872732948625348, 'oneplus'),
#   Text(0.7203467471951871, -0.8313245839052958, 'samsung'),
#   Text(1.199001363081995, 0.04894620851014154, 'nokia'),
#   Text(-0.28831175313482715, 1.0615443151391857, 'redmi')],
#  [Text(-0.35464869834828566, -0.48396725174320077, '29.87'),
#   Text(0.39291640756101115, -0.4534497730392522, '12.99'),
#   Text(0.6994174617978304, 0.028551954964249227, '15.58'),
#   Text(-0.15726095625536027, 0.5790241718941012, '41.56')])

# %%
import pandas as pd
data=pd.read_excel("expense3.xlsx")
df=pd.DataFrame(data)
df.head(10)
grouped_by=df.groupby("Payment Mode")["Amount"].sum()
plt.pie(df["Amount"])
print(grouped_by)
# Out:
# Payment Mode
# Card      780
# Cash     4637
# UPI     23305
# Name: Amount, dtype: int64

# %%
ex=[0,0,0.1]
plt.pie(grouped_by.values,labels=grouped_by.index,shadow=True,autopct="%.2f",explode=ex)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd168f1c4d0>,
# ...
#  [Text(1.0959990892813076, 0.09373364547772882, 'Card'),
#   Text(0.8568333152505959, 0.6898091546773448, 'Cash'),
#   Text(-0.9954514431020451, -0.6701316470858962, 'UPI')],
#  [Text(0.5978176850625314, 0.05112744298785208, '2.72'),
#   Text(0.467363626500325, 0.3762595389149153, '16.14'),
#   Text(-0.5806800084761929, -0.3909101274667727, '81.14')])
