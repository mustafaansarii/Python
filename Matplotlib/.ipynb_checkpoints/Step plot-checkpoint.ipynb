# %%
import matplotlib.pyplot as plt
import pandas as pd
x=["day1","day2","day3","day4","day5"]
y=[10,20,30,40,50]
plt.step(x,y)

# %%
x=["day1","day2","day3","day4","day5"]
y=[60,24,32,42,50]
plt.step(x,y, where='post')

# %%
plt.step(x,y, where='mid',marker="*")

# %%
data=pd.read_excel("expense3.xlsx")
df=pd.DataFrame(data)
df['Amount'].fillna(0, inplace=True)
df['Amount'] = df['Amount'].astype(int, errors='ignore')
group=df.groupby("Category").agg({"Amount":"sum"})

# %%
group
# Out:
#             Amount
# Category
# 123            257
# Bills        18724
# Clothes       2890
# Essentials    4485
# Food          2765
# Grocery       1028

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 plt.step(group.index,group["Amount"])
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2876, in step(x, y, where, data, *args, **kwargs)
#    2874 @_copy_docstring_and_deprecators(Axes.step)
#    2875 def step(x, y, *args, where='pre', data=None, **kwargs):
# -> 2876     return gca().step(
#    2877         x, y, *args, where=where,
#    2878         **({"data": data} if data is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:2156, in Axes.step(self, x, y, where, data, *args, **kwargs)
#    2154 _api.check_in_list(('pre', 'post', 'mid'), where=where)
#    2155 kwargs['drawstyle'] = 'steps-' + where
# -> 2156 return self.plot(x, y, *args, data=data, **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1670, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
# -> 1670     self.add_line(line)
#    1671 if scalex:
#    1672     self._request_autoscale_view("x")
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2333, in _AxesBase.add_line(self, line)
#    2330 if line.get_clip_path() is None:
#    2331     line.set_clip_path(self.patch)
# -> 2333 self._update_line_limits(line)
#    2334 if not line.get_label():
#    2335     line.set_label(f'_child{len(self._children)}')
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:2356, in _AxesBase._update_line_limits(self, line)
#    2352 def _update_line_limits(self, line):
#    2353     """
#    2354     Figures out the data limit of the given line, updating self.dataLim.
#    2355     """
# -> 2356     path = line.get_path()
#    2357     if path.vertices.size == 0:
#    2358         return
#
# File /usr/lib/python3/dist-packages/matplotlib/lines.py:1031, in Line2D.get_path(self)
#    1029 """Return the `~matplotlib.path.Path` associated with this line."""
#    1030 if self._invalidy or self._invalidx:
# -> 1031     self.recache()
#    1032 return self._path
#
# File /usr/lib/python3/dist-packages/matplotlib/lines.py:659, in Line2D.recache(self, always)
#     657 if always or self._invalidx:
#     658     xconv = self.convert_xunits(self._xorig)
# --> 659     x = _to_unmasked_float_array(xconv).ravel()
#     660 else:
#     661     x = self._x
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1369, in _to_unmasked_float_array(x)
#    1367     return np.ma.asarray(x, float).filled(np.nan)
#    1368 else:
# -> 1369     return np.asarray(x, float)
#
# ValueError: could not convert string to float: 'Bills'
