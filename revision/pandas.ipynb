# %%
import numpy as np
import pandas as pd

# %%
dict1={"name":["mustafa","ram","sita"],
      "marks":[90,70,45],
      "city":["sitamarhi","delhi","mumbai"]}

# %%
print(dict1)
# Out:
# {'name': ['mustafa', 'ram', 'sita'], 'marks': [90, 70, 45], 'city': ['sitamarhi', 'delhi', 'mumbai']}

# %%
df=pd.DataFrame(dict1)
print(df)
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
df.to_csv("friend.csv")

# %%
df.to_csv("friend.csv", index=False)

# %%
df
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
df.tail(2)
# Out:
#    name  marks    city
# 1   ram     70   delhi
# 2  sita     45  mumbai

# %%
df.head(2)
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   68.333333
# std    22.546249
# min    45.000000
# 25%    57.500000
# 50%    70.000000
# 75%    80.000000
# max    90.000000

# %%
m=pd.read_csv("friend.csv")
m
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
p=pd.read_excel("expense3.xlsx")
p
# Out:
#    Client ID               Name  Age     Sex  Location ID Joined Bank  \
# 0   PKR81288      Raymond Mills   24    Male        34324  2019-05-06
# 1   PKR65833      Julia Spencer   23    Male        42205  2001-12-10
# 2   PKR47499     Stephen Murray   27  Female         7314  2010-01-25
# 3   PKR72498     Virginia Garza   40    Male        34594  1993-03-28
# 4   PKR60181    Melissa Sanders   46  Female        41269  2012-07-20
# 5   PKR78532      Samuel Hudson   23    Male        13204  2019-02-07
# 6   PKR95683  Timothy Alexander   46  Female        42910  2002-06-02
# 7   PKR40785        Carl Martin   78  Female         6127  2000-11-03
# 8   PKR13570         Philip Day   67  Female        32656  2015-04-07
# 9   PKR53299         Jason Sims   51    Male        28340  1995-11-20
# 10  PKR76263       Amy Martinez   55    Male        40459  2014-10-18
# 11  PKR56452     David Johnston   73  Female        25563  2005-09-12
# ...

# %%
p.describe()
# Out:
#              Age   Location ID  Estimated Income
# count  29.000000     29.000000         29.000000
# mean   49.379310  24656.758621     134530.453993
# std    14.341284  13482.781174      78755.178600
# min    23.000000   6127.000000      34404.160000
# 25%    41.000000   9505.000000      78892.520100
# 50%    51.000000  27913.000000     123545.419500
# 75%    58.000000  36232.000000     145704.553800
# max    78.000000  42910.000000     356808.112500

# %%
m
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
m["name"][0]="mohan"
# Out:
# /tmp/ipykernel_28998/740268845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m["name"][0]="mohan"

# %%
m
# Out:
#     name  marks       city
# 0  mohan     90  sitamarhi
# 1    ram     70      delhi
# 2   sita     45     mumbai

# %%
m.to_csv('friend.csv')
m
# Out:
#     name  marks       city
# 0  mohan     90  sitamarhi
# 1    ram     70      delhi
# 2   sita     45     mumbai

# %%
m.index=['first','second','third']

# %%
m
# Out:
#          name  marks       city
# first   mohan     90  sitamarhi
# second    ram     70      delhi
# third    sita     45     mumbai

# %%
ser=pd.Series(np.random.rand(30))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
n=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
n.head
# Out:
# <bound method NDFrame.head of             0         1         2         3         4
# 0    0.494356  0.848477  0.939441  0.534718  0.149483
# 1    0.601073  0.836196  0.334898  0.659826  0.930357
# 2    0.721489  0.837134  0.046107  0.797297  0.778125
# 3    0.873580  0.628854  0.244895  0.971171  0.100893
# 4    0.835675  0.043546  0.891554  0.754967  0.747366
# ..        ...       ...       ...       ...       ...
# 329  0.978133  0.695120  0.595678  0.889893  0.172562
# 330  0.079561  0.527696  0.414551  0.683783  0.715324
# 331  0.515329  0.702120  0.383047  0.215531  0.086463
# 332  0.608610  0.032724  0.569741  0.916355  0.774537
# 333  0.732787  0.548533  0.984428  0.229041  0.513535
#
# [334 rows x 5 columns]>

# %%
n.head(10)
# Out:
#           0         1         2         3         4
# 0  0.494356  0.848477  0.939441  0.534718  0.149483
# 1  0.601073  0.836196  0.334898  0.659826  0.930357
# 2  0.721489  0.837134  0.046107  0.797297  0.778125
# 3  0.873580  0.628854  0.244895  0.971171  0.100893
# 4  0.835675  0.043546  0.891554  0.754967  0.747366
# 5  0.815827  0.817810  0.568928  0.010574  0.692804
# 6  0.583188  0.072532  0.312014  0.395848  0.909149
# 7  0.799521  0.567093  0.162286  0.152825  0.666175
# 8  0.576333  0.877690  0.055007  0.708046  0.785517
# 9  0.770380  0.609717  0.510356  0.924073  0.556469

# %%
n.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.535678    0.509214    0.506335    0.515687    0.516830
# std      0.285219    0.282690    0.281573    0.285731    0.291642
# min      0.002469    0.000962    0.004255    0.001196    0.000746
# 25%      0.282544    0.271902    0.254427    0.283203    0.262364
# 50%      0.570599    0.529572    0.513947    0.511267    0.541256
# 75%      0.772619    0.752446    0.758619    0.757915    0.761408
# max      0.995558    0.997708    0.998629    0.996939    0.999293

# %%
n.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
n.to_csv("n.csv")

# %%
a=pd.read_csv("nn.csv")

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..          ...       ...       ...       ...       ...       ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
a.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4'], dtype='object')

# %%
a.to_numpy()
# Out:
# array([[0.00000000e+00, 3.43775760e-01, 5.69294319e-01, 3.25079916e-01,
#         8.13112579e-01, 7.66932630e-01],
#        [1.00000000e+00, 6.40243720e-01, 4.62482833e-01, 9.66850363e-01,
#         7.72857250e-01, 1.36718778e-01],
#        [2.00000000e+00, 8.64880699e-01, 6.99735339e-01, 8.22199274e-01,
#         8.82697322e-01, 9.63571108e-02],
#        ...,
#        [3.31000000e+02, 4.53307654e-01, 6.63268048e-01, 2.47018013e-01,
#         1.66755349e-01, 9.24306833e-01],
#        [3.32000000e+02, 4.01414181e-01, 9.00523681e-03, 4.79695653e-01,
#         8.98542539e-01, 9.97408776e-01],
#        [3.33000000e+02, 5.25050864e-01, 8.43170105e-01, 1.18000577e-01,
#         7.49737689e-01, 3.84178646e-01]])

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..          ...       ...       ...       ...       ...       ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a[1]=100

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
a.T
# Out:
#                    0           1           2           3           4    \
# Unnamed: 0    0.000000    1.000000    2.000000    3.000000    4.000000
# 0             0.343776    0.640244    0.864881    0.784819    0.572958
# 1             0.569294    0.462483    0.699735    0.672336    0.924423
# 2             0.325080    0.966850    0.822199    0.975565    0.926268
# 3             0.813113    0.772857    0.882697    0.834717    0.623340
# 4             0.766933    0.136719    0.096357    0.249611    0.482885
# 1           100.000000  100.000000  100.000000  100.000000  100.000000
#
#                    5           6           7           8           9    ...  \
# Unnamed: 0    5.000000    6.000000    7.000000    8.000000    9.000000  ...
# 0             0.429201    0.481694    0.457112    0.471850    0.812483  ...
# 1             0.462731    0.293145    0.718885    0.655941    0.440338  ...
# 2             0.008973    0.353749    0.445563    0.109741    0.994707  ...
# ...

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
a.sort_index(axis=0, ascending=0)
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
#
# [334 rows x 7 columns]

# %%
a[1]
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 329    100
# 330    100
# 331    100
# 332    100
# 333    100
# Name: 1, Length: 334, dtype: int64

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
n2=a

# %%
n2
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]

# %%
n2[1][0]=999
# Out:
# /tmp/ipykernel_28998/2911890798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n2[1][0]=999

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  999
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]
