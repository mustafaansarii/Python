# %%
import numpy as np
import pandas as pd

# %%
dict1={"name":["mustafa","ram","sita"],
      "marks":[90,70,45],
      "city":["sitamarhi","delhi","mumbai"]}

# %%
print(dict1)
# Out:
# {'name': ['mustafa', 'ram', 'sita'], 'marks': [90, 70, 45], 'city': ['sitamarhi', 'delhi', 'mumbai']}

# %%
df=pd.DataFrame(dict1)
print(df)
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
df.to_csv("friend.csv")

# %%
df.to_csv("friend.csv", index=False)

# %%
df
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
df.tail(2)
# Out:
#    name  marks    city
# 1   ram     70   delhi
# 2  sita     45  mumbai

# %%
df.head(2)
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   68.333333
# std    22.546249
# min    45.000000
# 25%    57.500000
# 50%    70.000000
# 75%    80.000000
# max    90.000000

# %%
m=pd.read_csv("friend.csv")
m
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
p=pd.read_excel("expense3.xlsx")
p
# Out:
#     Unnamed: 0.1  Unnamed: 0       Date    Category       Sub-Category   \
# 0              0  2023-05-01 2023-05-01     Grocery  Fruits and Veggies
# 1              1           1 2023-02-02     Grocery                Milk
# 2              2           2 2023-02-03        Food          Restaurant
# 3              3           3 2023-02-04        Food  Fruits and Veggies
# 4              4           4 2023-02-05        Food              Zomato
# 5              5           5 2023-02-06        Food              Zomato
# 6              6           6 2023-02-06     Grocery           Chocolate
# 7              7           7 2023-02-08     Grocery      Bread and Milk
# 8              8           8 2023-02-09     Grocery             Grocery
# 9              9           9 2023-02-10        Food          Restaurant
# 10            10          10 2023-02-11  Essentials             Shampoo
# 11            11          11 2023-02-11  Essentials            Food Oil
# ...

# %%
p.describe()
# Out:
#        Unnamed: 0.1        Amount
# count     29.000000     29.000000
# mean      14.000000   1075.241379
# std        8.514693   2921.428206
# min        0.000000     10.000000
# 25%        7.000000    100.000000
# 50%       14.000000    400.000000
# 75%       21.000000   1000.000000
# max       28.000000  16000.000000

# %%
m
# Out:
#       name  marks       city
# 0  mustafa     90  sitamarhi
# 1      ram     70      delhi
# 2     sita     45     mumbai

# %%
m["name"][0]="mohan"
# Out:
# /tmp/ipykernel_38830/740268845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m["name"][0]="mohan"

# %%
m
# Out:
#     name  marks       city
# 0  mohan     90  sitamarhi
# 1    ram     70      delhi
# 2   sita     45     mumbai

# %%
m.to_csv('friend.csv')
m
# Out:
#     name  marks       city
# 0  mohan     90  sitamarhi
# 1    ram     70      delhi
# 2   sita     45     mumbai

# %%
m.index=['first','second','third']

# %%
m
# Out:
#          name  marks       city
# first   mohan     90  sitamarhi
# second    ram     70      delhi
# third    sita     45     mumbai

# %%
ser=pd.Series(np.random.rand(30))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
n=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
n.head
# Out:
# <bound method NDFrame.head of             0         1         2         3         4
# 0    0.100110  0.191822  0.923000  0.330109  0.726904
# 1    0.014522  0.086363  0.085836  0.385479  0.300528
# 2    0.748710  0.919992  0.600523  0.155841  0.476055
# 3    0.890819  0.834177  0.313689  0.569440  0.744329
# 4    0.038350  0.429823  0.971531  0.637038  0.492650
# ..        ...       ...       ...       ...       ...
# 329  0.720084  0.439956  0.440621  0.830335  0.666598
# 330  0.344488  0.667176  0.278356  0.720032  0.184717
# 331  0.174830  0.238722  0.516230  0.548333  0.272477
# 332  0.202892  0.886059  0.865066  0.316407  0.205384
# 333  0.772428  0.879917  0.138342  0.714187  0.479195
#
# [334 rows x 5 columns]>

# %%
n.head(10)
# Out:
#           0         1         2         3         4
# 0  0.100110  0.191822  0.923000  0.330109  0.726904
# 1  0.014522  0.086363  0.085836  0.385479  0.300528
# 2  0.748710  0.919992  0.600523  0.155841  0.476055
# 3  0.890819  0.834177  0.313689  0.569440  0.744329
# 4  0.038350  0.429823  0.971531  0.637038  0.492650
# 5  0.970890  0.587088  0.918903  0.995965  0.902648
# 6  0.800709  0.426237  0.694135  0.286781  0.458248
# 7  0.210950  0.949895  0.775182  0.526702  0.599945
# 8  0.585383  0.616682  0.962355  0.529730  0.922186
# 9  0.977643  0.938378  0.876246  0.617253  0.187023

# %%
n.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.472609    0.468359    0.494745    0.520052    0.494019
# std      0.283136    0.289001    0.292342    0.275365    0.296828
# min      0.002616    0.006817    0.001212    0.007806    0.001705
# 25%      0.229485    0.212207    0.256301    0.300982    0.229711
# 50%      0.456786    0.449309    0.481794    0.531931    0.484382
# 75%      0.709082    0.711528    0.757709    0.737910    0.744777
# max      0.996097    0.999430    0.995555    0.996996    0.997999

# %%
n.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
n.to_csv("n.csv")

# %%
a=pd.read_csv("nn.csv")

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..          ...       ...       ...       ...       ...       ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.index
# Out:
# RangeIndex(start=0, stop=334, step=1)

# %%
a.columns
# Out:
# Index(['Unnamed: 0', '0', '1', '2', '3', '4'], dtype='object')

# %%
a.to_numpy()
# Out:
# array([[0.00000000e+00, 3.43775760e-01, 5.69294319e-01, 3.25079916e-01,
#         8.13112579e-01, 7.66932630e-01],
#        [1.00000000e+00, 6.40243720e-01, 4.62482833e-01, 9.66850363e-01,
#         7.72857250e-01, 1.36718778e-01],
#        [2.00000000e+00, 8.64880699e-01, 6.99735339e-01, 8.22199274e-01,
#         8.82697322e-01, 9.63571108e-02],
#        ...,
#        [3.31000000e+02, 4.53307654e-01, 6.63268048e-01, 2.47018013e-01,
#         1.66755349e-01, 9.24306833e-01],
#        [3.32000000e+02, 4.01414181e-01, 9.00523681e-03, 4.79695653e-01,
#         8.98542539e-01, 9.97408776e-01],
#        [3.33000000e+02, 5.25050864e-01, 8.43170105e-01, 1.18000577e-01,
#         7.49737689e-01, 3.84178646e-01]])

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..          ...       ...       ...       ...       ...       ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a[1]=100

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
a.T
# Out:
#                    0           1           2           3           4    \
# Unnamed: 0    0.000000    1.000000    2.000000    3.000000    4.000000
# 0             0.343776    0.640244    0.864881    0.784819    0.572958
# 1             0.569294    0.462483    0.699735    0.672336    0.924423
# 2             0.325080    0.966850    0.822199    0.975565    0.926268
# 3             0.813113    0.772857    0.882697    0.834717    0.623340
# 4             0.766933    0.136719    0.096357    0.249611    0.482885
# 1           100.000000  100.000000  100.000000  100.000000  100.000000
#
#                    5           6           7           8           9    ...  \
# Unnamed: 0    5.000000    6.000000    7.000000    8.000000    9.000000  ...
# 0             0.429201    0.481694    0.457112    0.471850    0.812483  ...
# 1             0.462731    0.293145    0.718885    0.655941    0.440338  ...
# 2             0.008973    0.353749    0.445563    0.109741    0.994707  ...
# ...

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
a.sort_index(axis=0, ascending=0)
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
#
# [334 rows x 7 columns]

# %%
a[1]
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 329    100
# 330    100
# 331    100
# 332    100
# 333    100
# Name: 1, Length: 334, dtype: int64

# %%
a.head()
# Out:
#    Unnamed: 0         0         1         2         3         4    1
# 0           0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1           1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2           2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3           3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4           4  0.572958  0.924423  0.926268  0.623340  0.482885  100

# %%
n2=a

# %%
n2
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  100
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]

# %%
n2[1][0]=999
# Out:
# /tmp/ipykernel_38830/2911890798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n2[1][0]=999

# %%
a
# Out:
#      Unnamed: 0         0         1         2         3         4    1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  999
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719  100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357  100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611  100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885  100
# ..          ...       ...       ...       ...       ...       ...  ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659  100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971  100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307  100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409  100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179  100
#
# [334 rows x 7 columns]

# %%
n2=a.copy()

# %%
n2[1][0]=9999
# Out:
# /tmp/ipykernel_38830/3027670483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n2[1][0]=9999

# %%
n2
# Out:
#      Unnamed: 0         0         1         2         3         4     1
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  9999
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719   100
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357   100
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611   100
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885   100
# ..          ...       ...       ...       ...       ...       ...   ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659   100
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971   100
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307   100
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409   100
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179   100
#
# [334 rows x 7 columns]

# %%
n2.loc[0,0]=556
n2
# Out:
#      Unnamed: 0         0         1         2         3         4     1      0
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933  9999  556.0
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719   100    NaN
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357   100    NaN
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611   100    NaN
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885   100    NaN
# ..          ...       ...       ...       ...       ...       ...   ...    ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659   100    NaN
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971   100    NaN
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307   100    NaN
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409   100    NaN
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179   100    NaN
#
# [334 rows x 8 columns]

# %%
n2.columns=list("ABCDEFGH")
n2
# Out:
#        A         B         C         D         E         F     G      H
# 0      0  0.343776  0.569294  0.325080  0.813113  0.766933  9999  556.0
# 1      1  0.640244  0.462483  0.966850  0.772857  0.136719   100    NaN
# 2      2  0.864881  0.699735  0.822199  0.882697  0.096357   100    NaN
# 3      3  0.784819  0.672336  0.975565  0.834717  0.249611   100    NaN
# 4      4  0.572958  0.924423  0.926268  0.623340  0.482885   100    NaN
# ..   ...       ...       ...       ...       ...       ...   ...    ...
# 329  329  0.208056  0.035477  0.453279  0.803810  0.569659   100    NaN
# 330  330  0.623343  0.438824  0.236382  0.099615  0.397971   100    NaN
# 331  331  0.453308  0.663268  0.247018  0.166755  0.924307   100    NaN
# 332  332  0.401414  0.009005  0.479696  0.898543  0.997409   100    NaN
# 333  333  0.525051  0.843170  0.118001  0.749738  0.384179   100    NaN
#
# [334 rows x 8 columns]

# %%
n2.head()
# Out:
#    A         B         C         D         E         F     G      H
# 0  0  0.343776  0.569294  0.325080  0.813113  0.766933  9999  556.0
# 1  1  0.640244  0.462483  0.966850  0.772857  0.136719   100    NaN
# 2  2  0.864881  0.699735  0.822199  0.882697  0.096357   100    NaN
# 3  3  0.784819  0.672336  0.975565  0.834717  0.249611   100    NaN
# 4  4  0.572958  0.924423  0.926268  0.623340  0.482885   100    NaN

# %%
n2.loc[0,'A']=555
n2.head()
# Out:
#      A         B         C         D         E         F     G      H
# 0  555  0.343776  0.569294  0.325080  0.813113  0.766933  9999  556.0
# 1    1  0.640244  0.462483  0.966850  0.772857  0.136719   100    NaN
# 2    2  0.864881  0.699735  0.822199  0.882697  0.096357   100    NaN
# 3    3  0.784819  0.672336  0.975565  0.834717  0.249611   100    NaN
# 4    4  0.572958  0.924423  0.926268  0.623340  0.482885   100    NaN

# %%
print(n2)
# n2=n2.drop(1,axis=0)
n2.shape
# Out:
#        A         B         C         D         E         F     G      H
# 0    555  0.343776  0.569294  0.325080  0.813113  0.766933  9999  556.0
# 1      1  0.640244  0.462483  0.966850  0.772857  0.136719   100    NaN
# 2      2  0.864881  0.699735  0.822199  0.882697  0.096357   100    NaN
# 3      3  0.784819  0.672336  0.975565  0.834717  0.249611   100    NaN
# 4      4  0.572958  0.924423  0.926268  0.623340  0.482885   100    NaN
# ..   ...       ...       ...       ...       ...       ...   ...    ...
# 329  329  0.208056  0.035477  0.453279  0.803810  0.569659   100    NaN
# 330  330  0.623343  0.438824  0.236382  0.099615  0.397971   100    NaN
# 331  331  0.453308  0.663268  0.247018  0.166755  0.924307   100    NaN
# 332  332  0.401414  0.009005  0.479696  0.898543  0.997409   100    NaN
# 333  333  0.525051  0.843170  0.118001  0.749738  0.384179   100    NaN
#
# [334 rows x 8 columns]
# (334, 8)

# %%
a=pd.read_csv("nn.csv")
a
# Out:
#      Unnamed: 0         0         1         2         3         4
# 0             0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1             1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2             2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3             3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4             4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..          ...       ...       ...       ...       ...       ...
# 329         329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330         330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331         331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332         332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333         333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.columns=list("ABCDEF")
a
# Out:
#        A         B         C         D         E         F
# 0      0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1      1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2      2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3      3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4      4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..   ...       ...       ...       ...       ...       ...
# 329  329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330  330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331  331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332  332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333  333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.loc[[1,2]]
# Out:
#    A         B         C         D         E         F
# 1  1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2  2  0.864881  0.699735  0.822199  0.882697  0.096357

# %%
a.loc[(a['A']<1.3) & (a['B']<1.3)]
# Out:
#    A         B         C        D         E         F
# 0  0  0.343776  0.569294  0.32508  0.813113  0.766933
# 1  1  0.640244  0.462483  0.96685  0.772857  0.136719

# %%
a.head()
# Out:
#    A         B         C         D         E         F
# 0  0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1  1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2  2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3  3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4  4  0.572958  0.924423  0.926268  0.623340  0.482885

# %%
a.iloc[1,3]
# Out:
# 0.9668503631137024

# %%
a.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.343776  0.569294
# 1  0.640244  0.462483

# %%
a.head(3)
# Out:
#    A         B         C         D         E         F
# 0  0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1  1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2  2  0.864881  0.699735  0.822199  0.882697  0.096357

# %%
a.drop([0],axis=0)
# Out:
#        A         B         C         D         E         F
# 1      1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2      2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3      3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4      4  0.572958  0.924423  0.926268  0.623340  0.482885
# 5      5  0.429201  0.462731  0.008973  0.581760  0.629878
# ..   ...       ...       ...       ...       ...       ...
# 329  329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330  330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331  331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332  332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333  333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [333 rows x 6 columns]

# %%
a.drop(['A','B'],axis=1)
# Out:
#             C         D         E         F
# 0    0.569294  0.325080  0.813113  0.766933
# 1    0.462483  0.966850  0.772857  0.136719
# 2    0.699735  0.822199  0.882697  0.096357
# 3    0.672336  0.975565  0.834717  0.249611
# 4    0.924423  0.926268  0.623340  0.482885
# ..        ...       ...       ...       ...
# 329  0.035477  0.453279  0.803810  0.569659
# 330  0.438824  0.236382  0.099615  0.397971
# 331  0.663268  0.247018  0.166755  0.924307
# 332  0.009005  0.479696  0.898543  0.997409
# 333  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 4 columns]

# %%
a.head(3)
# Out:
#    A         B         C         D         E         F
# 0  0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1  1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2  2  0.864881  0.699735  0.822199  0.882697  0.096357

# %%
a.reset_index()
# Out:
#      index    A         B         C         D         E         F
# 0        0    0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1        1    1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2        2    2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3        3    3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4        4    4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..     ...  ...       ...       ...       ...       ...       ...
# 329    329  329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330    330  330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331    331  331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332    332  332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333    333  333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 7 columns]

# %%
a.dropna()
# Out:
#        A         B         C         D         E         F
# 0      0  0.343776  0.569294  0.325080  0.813113  0.766933
# 1      1  0.640244  0.462483  0.966850  0.772857  0.136719
# 2      2  0.864881  0.699735  0.822199  0.882697  0.096357
# 3      3  0.784819  0.672336  0.975565  0.834717  0.249611
# 4      4  0.572958  0.924423  0.926268  0.623340  0.482885
# ..   ...       ...       ...       ...       ...       ...
# 329  329  0.208056  0.035477  0.453279  0.803810  0.569659
# 330  330  0.623343  0.438824  0.236382  0.099615  0.397971
# 331  331  0.453308  0.663268  0.247018  0.166755  0.924307
# 332  332  0.401414  0.009005  0.479696  0.898543  0.997409
# 333  333  0.525051  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.isnull()
# Out:
#          A      B      C      D      E      F
# 0    False  False  False  False  False  False
# 1    False  False  False  False  False  False
# 2    False  False  False  False  False  False
# 3    False  False  False  False  False  False
# 4    False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...
# 329  False  False  False  False  False  False
# 330  False  False  False  False  False  False
# 331  False  False  False  False  False  False
# 332  False  False  False  False  False  False
# 333  False  False  False  False  False  False
#
# [334 rows x 6 columns]

# %%
a['B']=None

# %%
a
# Out:
#        A     B         C         D         E         F
# 0      0  None  0.569294  0.325080  0.813113  0.766933
# 1      1  None  0.462483  0.966850  0.772857  0.136719
# 2      2  None  0.699735  0.822199  0.882697  0.096357
# 3      3  None  0.672336  0.975565  0.834717  0.249611
# 4      4  None  0.924423  0.926268  0.623340  0.482885
# ..   ...   ...       ...       ...       ...       ...
# 329  329  None  0.035477  0.453279  0.803810  0.569659
# 330  330  None  0.438824  0.236382  0.099615  0.397971
# 331  331  None  0.663268  0.247018  0.166755  0.924307
# 332  332  None  0.009005  0.479696  0.898543  0.997409
# 333  333  None  0.843170  0.118001  0.749738  0.384179
#
# [334 rows x 6 columns]

# %%
a.isnull()
# Out:
#          A     B      C      D      E      F
# 0    False  True  False  False  False  False
# 1    False  True  False  False  False  False
# 2    False  True  False  False  False  False
# 3    False  True  False  False  False  False
# 4    False  True  False  False  False  False
# ..     ...   ...    ...    ...    ...    ...
# 329  False  True  False  False  False  False
# 330  False  True  False  False  False  False
# 331  False  True  False  False  False  False
# 332  False  True  False  False  False  False
# 333  False  True  False  False  False  False
#
# [334 rows x 6 columns]

# %%
a.loc[:,['B']]=None
a['B']
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 329    None
# 330    None
# 331    None
# 332    None
# 333    None
# Name: B, Length: 334, dtype: object

# %%
a.loc[:,['B']]='1'
a.head()
# Out:
#    A  B         C         D         E         F
# 0  0  1  0.569294  0.325080  0.813113  0.766933
# 1  1  1  0.462483  0.966850  0.772857  0.136719
# 2  2  1  0.699735  0.822199  0.882697  0.096357
# 3  3  1  0.672336  0.975565  0.834717  0.249611
# 4  4  1  0.924423  0.926268  0.623340  0.482885

# %%
dc={"name":["ram","ram",np.nan],
      "marks":[90,70,45],
      "city":["sitamarhi","delhi","mumbai"]}
dc
# Out:
# {'name': ['ram', 'ram', nan],
#  'marks': [90, 70, 45],
#  'city': ['sitamarhi', 'delhi', 'mumbai']}

# %%
cf=pd.DataFrame(dc)
print(cf)
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 1  ram     70      delhi
# 2  NaN     45     mumbai

# %%
cf.dropna()
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 1  ram     70      delhi

# %%
cf.dropna(how='all',axis=0)
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 1  ram     70      delhi
# 2  NaN     45     mumbai

# %%
df=cf.copy()

# %%
df
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 1  ram     70      delhi
# 2  NaN     45     mumbai

# %%
df.drop_duplicates(subset=['name'])
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 2  NaN     45     mumbai

# %%
df.drop_duplicates(subset=['name'])
# Out:
#   name  marks       city
# 0  ram     90  sitamarhi
# 2  NaN     45     mumbai

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
#   name  marks    city
# 2  NaN     45  mumbai

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   marks   3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#            marks
# count   3.000000
# mean   68.333333
# std    22.546249
# min    45.000000
# 25%    57.500000
# 50%    70.000000
# 75%    80.000000
# max    90.000000

# %%
df['name'].value_counts(dropna=False)
# Out:
# ram    2
# NaN    1
# Name: name, dtype: int64

# %%
df['name'].value_counts(dropna=True)
# Out:
# ram    2
# Name: name, dtype: int64

# %%
df.notnull()
# Out:
#     name  marks  city
# 0   True   True  True
# 1   True   True  True
# 2  False   True  True

# %%
# create a dataframe which contains only integers with 3 rows and 2 columns
# run following dataframe methods on them:
import pandas as pd
df={"m":[5,5,5],
   "a":[1,2,3]}
df=pd.DataFrame(df)
df
# Out:
#    m  a
# 0  5  1
# 1  5  2
# 2  5  3

# %%
df.describe()
# Out:
#          m    a
# count  3.0  3.0
# mean   5.0  2.0
# std    0.0  1.0
# min    5.0  1.0
# 25%    5.0  1.5
# 50%    5.0  2.0
# 75%    5.0  2.5
# max    5.0  3.0

# %%
df.mean()
# Out:
# m    5.0
# a    2.0
# dtype: float64

# %%
df.corr()
# Out:
#     m    a
# m NaN  NaN
# a NaN  1.0

# %%
df.count()
# Out:
# m    3
# a    3
# dtype: int64

# %%
df.max()
# Out:
# m    5
# a    3
# dtype: int64

# %%
df.min()
# Out:
# m    5
# a    1
# dtype: int64

# %%
df.median()
# Out:
# m    5.0
# a    2.0
# dtype: float64

# %%
df.std()
# Out:
# m    0.0
# a    1.0
# dtype: float64

# %%
df= pd.read_excel("expense3.xlsx")

# %%
df.iloc[0,0]="2023-05-01"
df
# Out:
#    Unnamed: 0.1  Unnamed: 0       Date    Category       Sub-Category   \
# 0    2023-05-01  2023-05-01 2023-05-01     Grocery  Fruits and Veggies
# 1             1           1 2023-02-02     Grocery                Milk
# 2             2           2 2023-02-03        Food          Restaurant
# 3             3           3 2023-02-04        Food  Fruits and Veggies
# 4             4           4 2023-02-05        Food              Zomato
# 5             5           5 2023-02-06        Food              Zomato
# 6             6           6 2023-02-06     Grocery           Chocolate
# 7             7           7 2023-02-08     Grocery      Bread and Milk
# 8             8           8 2023-02-09     Grocery             Grocery
# 9             9           9 2023-02-10        Food          Restaurant
# 10           10          10 2023-02-11  Essentials             Shampoo
# 11           11          11 2023-02-11  Essentials            Food Oil
# ...

# %%
df= pd.read_excel("expense3.xlsx", sheet_name='February')

# %%
df
# Out:
#     Unnamed: 0.1  Unnamed: 0       Date    Category       Sub-Category   \
# 0              0  2023-05-01 2023-05-01     Grocery  Fruits and Veggies
# 1              1           1 2023-02-02     Grocery                Milk
# 2              2           2 2023-02-03        Food          Restaurant
# 3              3           3 2023-02-04        Food  Fruits and Veggies
# 4              4           4 2023-02-05        Food              Zomato
# 5              5           5 2023-02-06        Food              Zomato
# 6              6           6 2023-02-06     Grocery           Chocolate
# 7              7           7 2023-02-08     Grocery      Bread and Milk
# 8              8           8 2023-02-09     Grocery             Grocery
# 9              9           9 2023-02-10        Food          Restaurant
# 10            10          10 2023-02-11  Essentials             Shampoo
# 11            11          11 2023-02-11  Essentials            Food Oil
# ...

# %%
df.iloc[0,0]="2023-05-01"

# %%
df
# Out:
#    Unnamed: 0.1  Unnamed: 0       Date    Category       Sub-Category   \
# 0    2023-05-01  2023-05-01 2023-05-01     Grocery  Fruits and Veggies
# 1             1           1 2023-02-02     Grocery                Milk
# 2             2           2 2023-02-03        Food          Restaurant
# 3             3           3 2023-02-04        Food  Fruits and Veggies
# 4             4           4 2023-02-05        Food              Zomato
# 5             5           5 2023-02-06        Food              Zomato
# 6             6           6 2023-02-06     Grocery           Chocolate
# 7             7           7 2023-02-08     Grocery      Bread and Milk
# 8             8           8 2023-02-09     Grocery             Grocery
# 9             9           9 2023-02-10        Food          Restaurant
# 10           10          10 2023-02-11  Essentials             Shampoo
# 11           11          11 2023-02-11  Essentials            Food Oil
# ...

# %%
df.to_excel("expense3.xlsx", sheet_name='February')

# %%
df.iloc[0,0]="2023-05-01"
df
# Out:
#    Unnamed: 0.1  Unnamed: 0       Date    Category       Sub-Category   \
# 0    2023-05-01  2023-05-01 2023-05-01     Grocery  Fruits and Veggies
# 1             1           1 2023-02-02     Grocery                Milk
# 2             2           2 2023-02-03        Food          Restaurant
# 3             3           3 2023-02-04        Food  Fruits and Veggies
# 4             4           4 2023-02-05        Food              Zomato
# 5             5           5 2023-02-06        Food              Zomato
# 6             6           6 2023-02-06     Grocery           Chocolate
# 7             7           7 2023-02-08     Grocery      Bread and Milk
# 8             8           8 2023-02-09     Grocery             Grocery
# 9             9           9 2023-02-10        Food          Restaurant
# 10           10          10 2023-02-11  Essentials             Shampoo
# 11           11          11 2023-02-11  Essentials            Food Oil
# ...
