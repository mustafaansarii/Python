# %% [raw]
# Scatter plots are a common and powerful way to visualize the relationship between two continuous variables. They display individual data points on a two-dimensional plane, with one variable on the x-axis and another on the y-axis. Scatter plots are useful for various purposes

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
data=sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data,x='total_bill',y='tip')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='smoker')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='day')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='day',size='size')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='day',marker="d")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='day',palette="spring")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data,x='total_bill',y='tip',hue='day',palette="viridis")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
data=pd.read_excel("ESD.xlsx")
data
sns.scatterplot(data,x="Age",y='Annual Salary')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Annual Salary'>

# %%
data
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
sns.scatterplot(data,x="Age",y='Annual Salary',size='Bonus %',hue='Gender',palette="viridis")
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Annual Salary'>

# %%
sns.scatterplot(data,x="Age",y='Annual Salary',size='Bonus %',hue='Gender',palette="viridis")
plt.legend(bbox_to_anchor=(0.2,0,1.1,1)) #x,y,width,height
